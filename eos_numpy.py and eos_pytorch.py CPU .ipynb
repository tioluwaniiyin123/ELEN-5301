# %% [markdown]
# <a href="https://colab.research.google.com/github/tioluwaniiyin123/ELEN-5301/blob/Benchmarking/eos_numpy.py%20and%20eos_pytorch.py%20CPU%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# EOS NumPy version
# !wget https://raw.githubusercontent.com/dionhaefner/pyhpc-benchmarks/master/benchmarks/equation_of_state/eos_numpy.py

# EOS PyTorch version
# !wget https://raw.githubusercontent.com/dionhaefner/pyhpc-benchmarks/master/benchmarks/equation_of_state/eos_pytorch.py
# Out:
# --2025-10-08 00:50:16--  https://raw.githubusercontent.com/dionhaefner/pyhpc-benchmarks/master/benchmarks/equation_of_state/eos_numpy.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6783 (6.6K) [text/plain]
# Saving to: ‘eos_numpy.py’
#
# eos_numpy.py        100%[===================>]   6.62K  --.-KB/s    in 0s
#
# 2025-10-08 00:50:16 (66.8 MB/s) - ‘eos_numpy.py’ saved [6783/6783]
#
# --2025-10-08 00:50:16--  https://raw.githubusercontent.com/dionhaefner/pyhpc-benchmarks/master/benchmarks/equation_of_state/eos_pytorch.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# ...

# %%
# Run NumPy benchmark
# !python eos_numpy.py

# Run PyTorch benchmark
# !python eos_pytorch.py

# %%
import time
start = time.time()
# !python eos_numpy.py
end = time.time()
execution_time = end - start
print(f"Execution Time (numpy on CPU): {execution_time:6f} seconds")
# Out:
# Execution Time (numpy on CPU): 0.204406 seconds

# %%
import torch

#device= "Cpu"
start = time.time()
# !python eos_pytorch.py
end = time.time()
execution_time = end - start
print(f"Execution Time (PyTorch on CPU):  {execution_time:6f} seconds ")
# Out:
# Execution Time (PyTorch on CPU):  2.613948 seconds
